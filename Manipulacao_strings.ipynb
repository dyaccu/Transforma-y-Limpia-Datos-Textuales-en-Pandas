# %% [markdown]
# <a href="https://colab.research.google.com/github/dyaccu/Transforma-y-Limpia-Datos-Textuales-en-Pandas/blob/main/Manipulacao_strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Transforma y Limpia Datos Textuales en Pandas**

# %% [markdown]
# ## Problema:
# La empresa FastDelivery, que ofrece un servicio de entrega de alimentos, cuenta con una base de datos de clientes y pedidos en constante crecimiento. Inicialmente, toda la información de sus clientes, como nombre, dirección y teléfono, se almacenaba en una hoja de cálculo simple en Excel. Sin embargo, con el tiempo, esa hoja ha crecido considerablemente, y ahora han decidido contratarte para manipular los datos y optimizar su análisis para estudios futuros.

# %%
# Importando la hoja de cálculo de datos de clientes
import pandas as pd

df = pd.read_excel("banco_clientes.xlsx")
df
# Out:
#               nombre                                direccion         telefono
# 0     Carlos Mendoza        Calle 22 de Abril, 12 52614-524      11 99548-2578
# 1   JavieR Fernández    Calle Alvarenga Borges, 573 29285-678    11 99999-1234
# 2      María López          Av. Buen Suceso 1283 87654-321       11 98765-4321
# 3     pedro martínez            Calle Colombo, 789 45678-912     11 91234-5678
# 4          ana gómez         Calle Dinamarca, 1011 34567-890     11 99876-5432
# 5    José Rodríguez               Av. Ermeson, 23456-789 1213  (11) 97654-3210
# 6     mariana castro       Calle de las Flores, 15 56789-123     11 95555-6789
# 7       LUCAS GARCÍA           Av. Governador, 1617 67890-234    11 94444-5678
# 8       Carla santos         Calle Hélio Gracie, 19 78901-345    11 93333-4567
# 9    Felipe Martínez        Av. 28 de Novembro, 221 89012-456  (11) 92222-7890
# 10      Amanda Pérez              Calle Joana 423 90123-567      11 91111-2345
# 11     Rafaela López                Av. Brasil, 245 01234-567  (11) 90000-5678
# 12     Eduardo Silva      Calle del Lamparao, 2627 12345-678   (11) 98888-9012
# 13  Gustavo Rodrígez       Calle del Chuvisco, 2829 23456-789  (11) 97777-2345
# 14    Fernanda Costa             Av. Goytacaz, 3031 34567-890    11 96666-5678
# 15      Renato Pérez          Av. Areia Negra, 45678-912 3233  (11) 95555-9012
# 16    Letícia RIVERA    Calle de las Palmeras, 3435 56789-123    11 94444-2345
# 17       MarÍa Silva                Av. Oliva, 3637 67890-234  (11) 93333-5678
# 18     Isabela Gómez                Calle Peri, 339 78901-345    11 92222-9012
# 19       Bruno Costa             Av. Balestrin 1337 89012-456    11 91111-2345
# 20     Vanessa Silva  Calle Nicolás Copérnico, 90123-567 1543  (11) 90000-5678

# %% [markdown]
# * Padronizar los nombres de los clientes en letra mayúscula
# * Padronizar la columna de teléfonos al formato XX XXXXX-XXXX
# * Crear una columna únicamente con los códigos postales
# * Separar la dirección en dos columnas: calle y número

# %% [markdown]
# ## Padronizar los nombres de los clientes en letra mayúscula

# %% [markdown]
# Para facilitar la búsqueda y evitar duplicidades causadas por variaciones en la capitalización de los nombres, se debe convertir todos los nombres a mayúsculas. Esto puede hacerse con una función que aplique .str.upper() a la columna de nombres.

# %%
# Convirtiendo todos los nombres de los clientes a mayúsculas para estandarizar la columna
df["nombre"] = df["nombre"].str.upper()
df.columns
# Out:
# Index(['nombre', 'direccion', 'telefono'], dtype='object')

# %% [markdown]
# ## Padronizar la columna de teléfonos al formato XX XXXXX-XXXX

# %% [markdown]
# Los números de teléfono deben tener un formato consistente para facilitar su lectura y uso. Debemos asegurarnos de que todos los teléfonos sigan el formato estándar de dos dígitos para el código de área (XX) seguido por un número de teléfono de nueve dígitos, con un guion separando los últimos cuatro dígitos. Para esto, podemos aplicar una función que formatee los números de manera adecuada.

# %%
# Eliminando los paréntesis de la columna 'telefono' para estandarizar el formato de los números
df.telefono.str.replace("(", "", regex=False)
# Out:
# 0      11 99548-2578
# 1      11 99999-1234
# 2      11 98765-4321
# 3      11 91234-5678
# 4      11 99876-5432
# 5     11) 97654-3210
# 6      11 95555-6789
# 7      11 94444-5678
# 8      11 93333-4567
# 9     11) 92222-7890
# 10     11 91111-2345
# 11    11) 90000-5678
# 12    11) 98888-9012
# 13    11) 97777-2345
# 14     11 96666-5678
# 15    11) 95555-9012
# 16     11 94444-2345
# 17    11) 93333-5678
# 18     11 92222-9012
# 19     11 91111-2345
# 20    11) 90000-5678
# Name: telefono, dtype: object

# %%
df.telefono.str.replace("(", "",regex=False).str.replace(")", "",regex=False)
# Out:
# 0     11 99548-2578
# 1     11 99999-1234
# 2     11 98765-4321
# 3     11 91234-5678
# 4     11 99876-5432
# 5     11 97654-3210
# 6     11 95555-6789
# 7     11 94444-5678
# 8     11 93333-4567
# 9     11 92222-7890
# 10    11 91111-2345
# 11    11 90000-5678
# 12    11 98888-9012
# 13    11 97777-2345
# 14    11 96666-5678
# 15    11 95555-9012
# 16    11 94444-2345
# 17    11 93333-5678
# 18    11 92222-9012
# 19    11 91111-2345
# 20    11 90000-5678
# Name: telefono, dtype: object

# %%
df["telefono"] = df.telefono.str.replace("(", "",regex=False).str.replace(")", "",regex=False)
df
# Out:
#               nombre                                direccion       telefono
# 0     CARLOS MENDOZA        Calle 22 de Abril, 12 52614-524    11 99548-2578
# 1   JAVIER FERNÁNDEZ    Calle Alvarenga Borges, 573 29285-678  11 99999-1234
# 2      MARÍA LÓPEZ          Av. Buen Suceso 1283 87654-321     11 98765-4321
# 3     PEDRO MARTÍNEZ            Calle Colombo, 789 45678-912   11 91234-5678
# 4          ANA GÓMEZ         Calle Dinamarca, 1011 34567-890   11 99876-5432
# 5    JOSÉ RODRÍGUEZ               Av. Ermeson, 23456-789 1213  11 97654-3210
# 6     MARIANA CASTRO       Calle de las Flores, 15 56789-123   11 95555-6789
# 7       LUCAS GARCÍA           Av. Governador, 1617 67890-234  11 94444-5678
# 8       CARLA SANTOS         Calle Hélio Gracie, 19 78901-345  11 93333-4567
# 9    FELIPE MARTÍNEZ        Av. 28 de Novembro, 221 89012-456  11 92222-7890
# 10      AMANDA PÉREZ              Calle Joana 423 90123-567    11 91111-2345
# 11     RAFAELA LÓPEZ                Av. Brasil, 245 01234-567  11 90000-5678
# 12     EDUARDO SILVA      Calle del Lamparao, 2627 12345-678   11 98888-9012
# 13  GUSTAVO RODRÍGEZ       Calle del Chuvisco, 2829 23456-789  11 97777-2345
# 14    FERNANDA COSTA             Av. Goytacaz, 3031 34567-890  11 96666-5678
# 15      RENATO PÉREZ          Av. Areia Negra, 45678-912 3233  11 95555-9012
# 16    LETÍCIA RIVERA    Calle de las Palmeras, 3435 56789-123  11 94444-2345
# 17       MARÍA SILVA                Av. Oliva, 3637 67890-234  11 93333-5678
# 18     ISABELA GÓMEZ                Calle Peri, 339 78901-345  11 92222-9012
# 19       BRUNO COSTA             Av. Balestrin 1337 89012-456  11 91111-2345
# 20     VANESSA SILVA  Calle Nicolás Copérnico, 90123-567 1543  11 90000-5678

# %% [markdown]
# ## Crear una columna únicamente con los códigos postales

# %% [markdown]
# Si actualmente la columna de direcciones contiene el código postal mezclado con otros datos, es necesario extraerlo y colocarlo en una columna separada. Esto facilitará la segmentación y el análisis de datos por ubicación geográfica.

# %%
df.direccion.str.extract("(\d{5}-\d{3})")
# Out:
#             0
# 0   52614-524
# 1   29285-678
# 2   87654-321
# 3   45678-912
# 4   34567-890
# 5   23456-789
# 6   56789-123
# 7   67890-234
# 8   78901-345
# 9   89012-456
# 10  90123-567
# 11  01234-567
# 12  12345-678
# 13  23456-789
# 14  34567-890
# 15  45678-912
# 16  56789-123
# 17  67890-234
# 18  78901-345
# 19  89012-456
# 20  90123-567

# %% [markdown]
# **Expresión Regular (\d{5}-\d{3})**
# * \d: Representa un dígito (0-9).
# * {5}: Especifica que se deben buscar exactamente 5 dígitos consecutivos.
# * -: Busca el carácter guion literal que separa los dos grupos de dígitos.
# * \d{3}: Especifica que se deben buscar exactamente 3 dígitos consecutivos.

# %%
df["CP"] = df.direccion.str.extract("(\d{5}-\d{3})")
df
# Out:
#               nombre                                direccion       telefono  \
# 0     CARLOS MENDOZA        Calle 22 de Abril, 12 52614-524    11 99548-2578
# 1   JAVIER FERNÁNDEZ    Calle Alvarenga Borges, 573 29285-678  11 99999-1234
# 2      MARÍA LÓPEZ          Av. Buen Suceso 1283 87654-321     11 98765-4321
# 3     PEDRO MARTÍNEZ            Calle Colombo, 789 45678-912   11 91234-5678
# 4          ANA GÓMEZ         Calle Dinamarca, 1011 34567-890   11 99876-5432
# 5    JOSÉ RODRÍGUEZ               Av. Ermeson, 23456-789 1213  11 97654-3210
# 6     MARIANA CASTRO       Calle de las Flores, 15 56789-123   11 95555-6789
# 7       LUCAS GARCÍA           Av. Governador, 1617 67890-234  11 94444-5678
# 8       CARLA SANTOS         Calle Hélio Gracie, 19 78901-345  11 93333-4567
# 9    FELIPE MARTÍNEZ        Av. 28 de Novembro, 221 89012-456  11 92222-7890
# 10      AMANDA PÉREZ              Calle Joana 423 90123-567    11 91111-2345
# 11     RAFAELA LÓPEZ                Av. Brasil, 245 01234-567  11 90000-5678
# 12     EDUARDO SILVA      Calle del Lamparao, 2627 12345-678   11 98888-9012
# 13  GUSTAVO RODRÍGEZ       Calle del Chuvisco, 2829 23456-789  11 97777-2345
# 14    FERNANDA COSTA             Av. Goytacaz, 3031 34567-890  11 96666-5678
# 15      RENATO PÉREZ          Av. Areia Negra, 45678-912 3233  11 95555-9012
# 16    LETÍCIA RIVERA    Calle de las Palmeras, 3435 56789-123  11 94444-2345
# 17       MARÍA SILVA                Av. Oliva, 3637 67890-234  11 93333-5678
# 18     ISABELA GÓMEZ                Calle Peri, 339 78901-345  11 92222-9012
# 19       BRUNO COSTA             Av. Balestrin 1337 89012-456  11 91111-2345
# 20     VANESSA SILVA  Calle Nicolás Copérnico, 90123-567 1543  11 90000-5678
#
#            CP
# 0   52614-524
# 1   29285-678
# 2   87654-321
# 3   45678-912
# 4   34567-890
# 5   23456-789
# 6   56789-123
# 7   67890-234
# 8   78901-345
# 9   89012-456
# 10  90123-567
# 11  01234-567
# 12  12345-678
# 13  23456-789
# 14  34567-890
# 15  45678-912
# 16  56789-123
# 17  67890-234
# 18  78901-345
# 19  89012-456
# 20  90123-567

# %%
df.direccion.str.replace('\d{5}-\d{3}', '', regex=True)
# Out:
# 0           Calle 22 de Abril, 12
# 1       Calle Alvarenga Borges, 573
# 2           Av. Buen Suceso 1283
# 3               Calle Colombo, 789
# 4            Calle Dinamarca, 1011
# 5                 Av. Ermeson,  1213
# 6          Calle de las Flores, 15
# 7              Av. Governador, 1617
# 8            Calle Hélio Gracie, 19
# 9           Av. 28 de Novembro, 221
# 10                Calle Joana 423
# 11                  Av. Brasil, 245
# 12        Calle del Lamparao, 2627
# 13         Calle del Chuvisco, 2829
# 14               Av. Goytacaz, 3031
# 15            Av. Areia Negra,  3233
# 16      Calle de las Palmeras, 3435
# 17                  Av. Oliva, 3637
# 18                  Calle Peri, 339
# 19               Av. Balestrin 1337
# 20    Calle Nicolás Copérnico,  1543
# Name: direccion, dtype: object

# %%
df['dirección'] = df.direccion.str.replace(r'\d{5}-\d{3}', '', regex=True).str.strip()
df
# Out:
#               nombre                                direccion       telefono  \
# 0     CARLOS MENDOZA        Calle 22 de Abril, 12 52614-524    11 99548-2578
# 1   JAVIER FERNÁNDEZ    Calle Alvarenga Borges, 573 29285-678  11 99999-1234
# 2      MARÍA LÓPEZ          Av. Buen Suceso 1283 87654-321     11 98765-4321
# 3     PEDRO MARTÍNEZ            Calle Colombo, 789 45678-912   11 91234-5678
# 4          ANA GÓMEZ         Calle Dinamarca, 1011 34567-890   11 99876-5432
# 5    JOSÉ RODRÍGUEZ               Av. Ermeson, 23456-789 1213  11 97654-3210
# 6     MARIANA CASTRO       Calle de las Flores, 15 56789-123   11 95555-6789
# 7       LUCAS GARCÍA           Av. Governador, 1617 67890-234  11 94444-5678
# 8       CARLA SANTOS         Calle Hélio Gracie, 19 78901-345  11 93333-4567
# 9    FELIPE MARTÍNEZ        Av. 28 de Novembro, 221 89012-456  11 92222-7890
# 10      AMANDA PÉREZ              Calle Joana 423 90123-567    11 91111-2345
# 11     RAFAELA LÓPEZ                Av. Brasil, 245 01234-567  11 90000-5678
# 12     EDUARDO SILVA      Calle del Lamparao, 2627 12345-678   11 98888-9012
# 13  GUSTAVO RODRÍGEZ       Calle del Chuvisco, 2829 23456-789  11 97777-2345
# 14    FERNANDA COSTA             Av. Goytacaz, 3031 34567-890  11 96666-5678
# 15      RENATO PÉREZ          Av. Areia Negra, 45678-912 3233  11 95555-9012
# 16    LETÍCIA RIVERA    Calle de las Palmeras, 3435 56789-123  11 94444-2345
# 17       MARÍA SILVA                Av. Oliva, 3637 67890-234  11 93333-5678
# 18     ISABELA GÓMEZ                Calle Peri, 339 78901-345  11 92222-9012
# 19       BRUNO COSTA             Av. Balestrin 1337 89012-456  11 91111-2345
# 20     VANESSA SILVA  Calle Nicolás Copérnico, 90123-567 1543  11 90000-5678
#
#            CP                       dirección
# 0   52614-524           Calle 22 de Abril, 12
# 1   29285-678     Calle Alvarenga Borges, 573
# 2   87654-321            Av. Buen Suceso 1283
# 3   45678-912              Calle Colombo, 789
# 4   34567-890           Calle Dinamarca, 1011
# 5   23456-789              Av. Ermeson,  1213
# 6   56789-123         Calle de las Flores, 15
# 7   67890-234            Av. Governador, 1617
# 8   78901-345          Calle Hélio Gracie, 19
# 9   89012-456         Av. 28 de Novembro, 221
# 10  90123-567                 Calle Joana 423
# 11  01234-567                 Av. Brasil, 245
# 12  12345-678        Calle del Lamparao, 2627
# 13  23456-789        Calle del Chuvisco, 2829
# 14  34567-890              Av. Goytacaz, 3031
# 15  45678-912          Av. Areia Negra,  3233
# 16  56789-123     Calle de las Palmeras, 3435
# 17  67890-234                 Av. Oliva, 3637
# 18  78901-345                 Calle Peri, 339
# 19  89012-456              Av. Balestrin 1337
# 20  90123-567  Calle Nicolás Copérnico,  1543

# %% [markdown]
# ## Separar la dirección en dos columnas: calle y número

# %% [markdown]
#  La dirección del cliente debe dividirse en dos columnas: una para la calle (o nombre de la vía) y otra para el número de la casa o apartamento. Esto permite un análisis más preciso y simplifica las búsquedas o el uso de la información para futuras operaciones logísticas.

# %%
df.direccion.str.split(',', expand=True)
# Out:
#                                     0                 1
# 0                   Calle 22 de Abril    12 52614-524
# 1              Calle Alvarenga Borges     573 29285-678
# 2   Av. Buen Suceso 1283 87654-321                 None
# 3                       Calle Colombo    789 45678-912
# 4                     Calle Dinamarca   1011 34567-890
# 5                         Av. Ermeson    23456-789 1213
# 6                 Calle de las Flores     15 56789-123
# 7                      Av. Governador    1617 67890-234
# 8                  Calle Hélio Gracie      19 78901-345
# 9                  Av. 28 de Novembro     221 89012-456
# 10        Calle Joana 423 90123-567                None
# 11                         Av. Brasil     245 01234-567
# 12                 Calle del Lamparao   2627 12345-678
# 13                 Calle del Chuvisco    2829 23456-789
# 14                       Av. Goytacaz    3031 34567-890
# 15                    Av. Areia Negra    45678-912 3233
# 16              Calle de las Palmeras    3435 56789-123
# 17                          Av. Oliva    3637 67890-234
# 18                         Calle Peri     339 78901-345
# 19       Av. Balestrin 1337 89012-456              None
# 20            Calle Nicolás Copérnico    90123-567 1543

# %%
df.direccion.str.split('\s(?=\d+$)', expand=True)
# Out:
#                                         0     1
# 0       Calle 22 de Abril, 12 52614-524    None
# 1   Calle Alvarenga Borges, 573 29285-678  None
# 2       Av. Buen Suceso 1283 87654-321     None
# 3           Calle Colombo, 789 45678-912   None
# 4        Calle Dinamarca, 1011 34567-890   None
# 5                  Av. Ermeson, 23456-789  1213
# 6      Calle de las Flores, 15 56789-123   None
# 7          Av. Governador, 1617 67890-234  None
# 8        Calle Hélio Gracie, 19 78901-345  None
# 9       Av. 28 de Novembro, 221 89012-456  None
# 10            Calle Joana 423 90123-567    None
# 11              Av. Brasil, 245 01234-567  None
# 12    Calle del Lamparao, 2627 12345-678   None
# 13     Calle del Chuvisco, 2829 23456-789  None
# 14           Av. Goytacaz, 3031 34567-890  None
# 15             Av. Areia Negra, 45678-912  3233
# 16  Calle de las Palmeras, 3435 56789-123  None
# 17              Av. Oliva, 3637 67890-234  None
# 18              Calle Peri, 339 78901-345  None
# 19           Av. Balestrin 1337 89012-456  None
# 20     Calle Nicolás Copérnico, 90123-567  1543

# %% [markdown]
#  **La expresión regular  `\s(?=\d+$)`**
# * \s: Representa un espacio en blanco (como un espacio, tabulación, etc.).
# * (`?=\d+$`): Es una afirmación de anticipación positiva (lookahead) que verifica si la parte después del espacio consiste solo en dígitos (\d+) hasta el final de la cadena ($). En otras palabras, busca un espacio en blanco que esté seguido por dígitos hasta el final de la cadena.

# %%
df.direccion.str.replace(",","").str.split('\s(?=\d+$)', expand=True)
# Out:
#                                        0     1
# 0       Calle 22 de Abril 12 52614-524    None
# 1   Calle Alvarenga Borges 573 29285-678  None
# 2      Av. Buen Suceso 1283 87654-321     None
# 3           Calle Colombo 789 45678-912   None
# 4        Calle Dinamarca 1011 34567-890   None
# 5                  Av. Ermeson 23456-789  1213
# 6      Calle de las Flores 15 56789-123   None
# 7          Av. Governador 1617 67890-234  None
# 8        Calle Hélio Gracie 19 78901-345  None
# 9       Av. 28 de Novembro 221 89012-456  None
# 10           Calle Joana 423 90123-567    None
# 11              Av. Brasil 245 01234-567  None
# 12    Calle del Lamparao 2627 12345-678   None
# 13     Calle del Chuvisco 2829 23456-789  None
# 14           Av. Goytacaz 3031 34567-890  None
# 15             Av. Areia Negra 45678-912  3233
# 16  Calle de las Palmeras 3435 56789-123  None
# 17              Av. Oliva 3637 67890-234  None
# 18              Calle Peri 339 78901-345  None
# 19          Av. Balestrin 1337 89012-456  None
# 20     Calle Nicolás Copérnico 90123-567  1543

# %%
df[["calle","numero"]] = df.direccion.str.replace(",","").str.split('\s(?=\d+$)',regex=True, expand=True)

# %%
df
# Out:
#               nombre                                direccion       telefono  \
# 0     CARLOS MENDOZA        Calle 22 de Abril, 12 52614-524    11 99548-2578
# 1   JAVIER FERNÁNDEZ    Calle Alvarenga Borges, 573 29285-678  11 99999-1234
# 2      MARÍA LÓPEZ          Av. Buen Suceso 1283 87654-321     11 98765-4321
# 3     PEDRO MARTÍNEZ            Calle Colombo, 789 45678-912   11 91234-5678
# 4          ANA GÓMEZ         Calle Dinamarca, 1011 34567-890   11 99876-5432
# 5    JOSÉ RODRÍGUEZ               Av. Ermeson, 23456-789 1213  11 97654-3210
# 6     MARIANA CASTRO       Calle de las Flores, 15 56789-123   11 95555-6789
# 7       LUCAS GARCÍA           Av. Governador, 1617 67890-234  11 94444-5678
# 8       CARLA SANTOS         Calle Hélio Gracie, 19 78901-345  11 93333-4567
# 9    FELIPE MARTÍNEZ        Av. 28 de Novembro, 221 89012-456  11 92222-7890
# 10      AMANDA PÉREZ              Calle Joana 423 90123-567    11 91111-2345
# 11     RAFAELA LÓPEZ                Av. Brasil, 245 01234-567  11 90000-5678
# 12     EDUARDO SILVA      Calle del Lamparao, 2627 12345-678   11 98888-9012
# 13  GUSTAVO RODRÍGEZ       Calle del Chuvisco, 2829 23456-789  11 97777-2345
# 14    FERNANDA COSTA             Av. Goytacaz, 3031 34567-890  11 96666-5678
# 15      RENATO PÉREZ          Av. Areia Negra, 45678-912 3233  11 95555-9012
# 16    LETÍCIA RIVERA    Calle de las Palmeras, 3435 56789-123  11 94444-2345
# 17       MARÍA SILVA                Av. Oliva, 3637 67890-234  11 93333-5678
# 18     ISABELA GÓMEZ                Calle Peri, 339 78901-345  11 92222-9012
# 19       BRUNO COSTA             Av. Balestrin 1337 89012-456  11 91111-2345
# 20     VANESSA SILVA  Calle Nicolás Copérnico, 90123-567 1543  11 90000-5678
#
#            CP                       dirección  \
# 0   52614-524           Calle 22 de Abril, 12
# 1   29285-678     Calle Alvarenga Borges, 573
# 2   87654-321            Av. Buen Suceso 1283
# 3   45678-912              Calle Colombo, 789
# 4   34567-890           Calle Dinamarca, 1011
# 5   23456-789              Av. Ermeson,  1213
# 6   56789-123         Calle de las Flores, 15
# 7   67890-234            Av. Governador, 1617
# 8   78901-345          Calle Hélio Gracie, 19
# 9   89012-456         Av. 28 de Novembro, 221
# 10  90123-567                 Calle Joana 423
# 11  01234-567                 Av. Brasil, 245
# 12  12345-678        Calle del Lamparao, 2627
# 13  23456-789        Calle del Chuvisco, 2829
# 14  34567-890              Av. Goytacaz, 3031
# 15  45678-912          Av. Areia Negra,  3233
# 16  56789-123     Calle de las Palmeras, 3435
# 17  67890-234                 Av. Oliva, 3637
# 18  78901-345                 Calle Peri, 339
# 19  89012-456              Av. Balestrin 1337
# 20  90123-567  Calle Nicolás Copérnico,  1543
#
#                                    calle numero
# 0       Calle 22 de Abril 12 52614-524     None
# 1   Calle Alvarenga Borges 573 29285-678   None
# 2      Av. Buen Suceso 1283 87654-321      None
# 3           Calle Colombo 789 45678-912    None
# 4        Calle Dinamarca 1011 34567-890    None
# 5                  Av. Ermeson 23456-789   1213
# 6      Calle de las Flores 15 56789-123    None
# 7          Av. Governador 1617 67890-234   None
# 8        Calle Hélio Gracie 19 78901-345   None
# 9       Av. 28 de Novembro 221 89012-456   None
# 10           Calle Joana 423 90123-567     None
# 11              Av. Brasil 245 01234-567   None
# 12    Calle del Lamparao 2627 12345-678    None
# 13     Calle del Chuvisco 2829 23456-789   None
# 14           Av. Goytacaz 3031 34567-890   None
# 15             Av. Areia Negra 45678-912   3233
# 16  Calle de las Palmeras 3435 56789-123   None
# 17              Av. Oliva 3637 67890-234   None
# 18              Calle Peri 339 78901-345   None
# 19          Av. Balestrin 1337 89012-456   None
# 20     Calle Nicolás Copérnico 90123-567   1543

# %%
df = df.drop(["direccion"], axis=1)
df
# Out:
#               nombre       telefono         CP  \
# 0     CARLOS MENDOZA  11 99548-2578  52614-524
# 1   JAVIER FERNÁNDEZ  11 99999-1234  29285-678
# 2      MARÍA LÓPEZ    11 98765-4321  87654-321
# 3     PEDRO MARTÍNEZ  11 91234-5678  45678-912
# 4          ANA GÓMEZ  11 99876-5432  34567-890
# 5    JOSÉ RODRÍGUEZ   11 97654-3210  23456-789
# 6     MARIANA CASTRO  11 95555-6789  56789-123
# 7       LUCAS GARCÍA  11 94444-5678  67890-234
# 8       CARLA SANTOS  11 93333-4567  78901-345
# 9    FELIPE MARTÍNEZ  11 92222-7890  89012-456
# 10      AMANDA PÉREZ  11 91111-2345  90123-567
# 11     RAFAELA LÓPEZ  11 90000-5678  01234-567
# 12     EDUARDO SILVA  11 98888-9012  12345-678
# 13  GUSTAVO RODRÍGEZ  11 97777-2345  23456-789
# 14    FERNANDA COSTA  11 96666-5678  34567-890
# 15      RENATO PÉREZ  11 95555-9012  45678-912
# 16    LETÍCIA RIVERA  11 94444-2345  56789-123
# 17       MARÍA SILVA  11 93333-5678  67890-234
# 18     ISABELA GÓMEZ  11 92222-9012  78901-345
# 19       BRUNO COSTA  11 91111-2345  89012-456
# 20     VANESSA SILVA  11 90000-5678  90123-567
#
#                          dirección                                 calle  \
# 0            Calle 22 de Abril, 12      Calle 22 de Abril 12 52614-524
# 1      Calle Alvarenga Borges, 573  Calle Alvarenga Borges 573 29285-678
# 2             Av. Buen Suceso 1283     Av. Buen Suceso 1283 87654-321
# 3               Calle Colombo, 789          Calle Colombo 789 45678-912
# 4            Calle Dinamarca, 1011       Calle Dinamarca 1011 34567-890
# 5               Av. Ermeson,  1213                 Av. Ermeson 23456-789
# 6          Calle de las Flores, 15     Calle de las Flores 15 56789-123
# 7             Av. Governador, 1617         Av. Governador 1617 67890-234
# 8           Calle Hélio Gracie, 19       Calle Hélio Gracie 19 78901-345
# 9          Av. 28 de Novembro, 221      Av. 28 de Novembro 221 89012-456
# 10                 Calle Joana 423           Calle Joana 423 90123-567
# 11                 Av. Brasil, 245              Av. Brasil 245 01234-567
# 12        Calle del Lamparao, 2627    Calle del Lamparao 2627 12345-678
# 13        Calle del Chuvisco, 2829     Calle del Chuvisco 2829 23456-789
# 14              Av. Goytacaz, 3031           Av. Goytacaz 3031 34567-890
# 15          Av. Areia Negra,  3233             Av. Areia Negra 45678-912
# 16     Calle de las Palmeras, 3435  Calle de las Palmeras 3435 56789-123
# 17                 Av. Oliva, 3637              Av. Oliva 3637 67890-234
# 18                 Calle Peri, 339              Calle Peri 339 78901-345
# 19              Av. Balestrin 1337          Av. Balestrin 1337 89012-456
# 20  Calle Nicolás Copérnico,  1543     Calle Nicolás Copérnico 90123-567
#
#    numero
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# 5    1213
# 6    None
# 7    None
# 8    None
# 9    None
# 10   None
# 11   None
# 12   None
# 13   None
# 14   None
# 15   3233
# 16   None
# 17   None
# 18   None
# 19   None
# 20   1543

# %%
df.to_csv("banco_clientes_procesado.csv", index=False)
